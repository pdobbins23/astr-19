# %% [markdown]
# # We can perform much more complicated fits

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize

# %%
npoints = 50

x = np.linspace(0., 2 * np.pi)

a = 3.4
b = 2.1
c = 0.27
d = -1.3
sig = 0.6

y = a * np.sin(b * x + c) + d + np.random.normal(scale=sig, size=npoints)
y_err = np.full(npoints, sig)

f = plt.figure(figsize=(7, 7))

plt.errorbar(x, y, yerr=y_err, fmt="o")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
def f_line(x, a, b, c, d):
    return a * np.sin(b * x + c) + d

params, params_cov = optimize.curve_fit(f_line, x, y, sigma=y_err, p0=[1, 2., 0.1, -0.1])

a_fit = params[0]
b_fit = params[1]
c_fit = params[2]
d_fit = params[3]

print(a_fit, b_fit, c_fit, d_fit)

y_fit = a_fit * np.sin(b_fit * x + c_fit) + d_fit
# Out:
# 3.30718082894233 2.074302166785866 0.4119330487668332 -1.1439766518792671

# %%
f = plt.figure(figsize=(7, 7))

plt.errorbar(x, y, yerr=y_err, fmt="o", label="data")
plt.plot(x, y_fit, label="fit")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc=0, frameon=False)

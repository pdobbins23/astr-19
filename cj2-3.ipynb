# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(1000)

width = 0.01

bins = np.arange(0, 1, width)
plt.hist(x, bins=bins, alpha=0.5, edgecolor="black")
plt.ylabel("N per bin")
plt.xlabel("x")
plt.savefig("cj2-3.pdf", bbox_inches="tight", facecolor="white")

# %% [markdown]
# #####
